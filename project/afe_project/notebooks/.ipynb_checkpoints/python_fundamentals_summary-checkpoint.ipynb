# %% [markdown]
# # Stage 03: Python Fundamentals
#
# **Date:** Aug 14 (Thursday) (C)
#
# In this notebook, we explore core Python data structures, NumPy, pandas, and reusable functions.

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime

# %% [markdown]
# ## Warm-Up: Function and Decorator

# %%
def calc_mean_std(lst):
    arr = np.array(lst)
    return arr.mean(), arr.std()

# %%
temp = (1,2,3)
print(*temp)
print(1,2,3)
# Out:
# 1 2 3
# 1 2 3

# %%
def my_func(y,*arg):
    print(arg)
    # for i in arg:
        # print(i)
my_func(1,2,3,'a')
# Out:
# (2, 3, 'a')

# %%
my_stock = {"stock":'appl',"quantity":500, "price":150}
my_stock2 = {"bond":'bootcamp',"expiry":'2026-01-01', "min":10000}
# print(list(my_stock.keys()))
# print(list(my_stock.values()))
# print(my_stock2)
{**my_stock  ,  **my_stock2 }
# Out:
# {'stock': 'appl',
#  'quantity': 500,
#  'price': 150,
#  'bond': 'bootcamp',
#  'expiry': '2026-01-01',
#  'min': 10000}

# %%
[my_stock[i] for i in my_stock]
# Out:
# ['appl', 500, 150]

# %%
def my_func(**args):
    print(args)
# my_func('appl',500, 150)
inputs = {'stock': 'appl', 'quantity': 500, 'price': 150,'fourth':444}
my_func(**inputs)
# my_func(stock='appl',quantity=500, price=150)
# Out:
# {'stock': 'appl', 'quantity': 500, 'price': 150, 'fourth': 444}

# %%
def my_debug(f):
    def new_func(*arg):
        print("arg length: "+str(len(arg)))
        f(*arg)
        # print(arg)
    return new_func
    
# a_func = my_debug( my_func )
# a_func(1,2,3)

@my_debug
def my_func(*args):
    print(args)

my_func(1,2,3)
# Out:
# arg length: 3
# (1, 2, 3)

# %%
def log_call(func):
    def wrapper(*args, **kwargs):
        print(f"Function {func.__name__} called at {datetime.now()}")
        return func(*args, **kwargs)
    return wrapper

# %%
@log_call
def calc_mean_std_logged(lst):
    return calc_mean_std(lst)

# %%
calc_mean_std_logged([1, 2, 3, 4, 5])
# Out:
# Function calc_mean_std_logged called at 2026-08-13 12:37:39.229117
# (np.float64(3.0), np.float64(1.4142135623730951))

# %% [markdown]
# ## Data Structures Comparison

# %%
lst = [1, 2, 3]
for i in lst:
    print(i)
[i*2 for i in lst]
arr = np.array(lst)
ser = pd.Series(lst)
df = pd.DataFrame({'col1': lst, 'col2': [4,5,6]})

print(type(lst), type(arr), type(ser), type(df))
# Out:
# 1
# 2
# 3
# <class 'list'> <class 'numpy.ndarray'> <class 'pandas.Series'> <class 'pandas.DataFrame'>

# %% [markdown]
# ## Vectorization vs Loops

# %%
big_array = np.arange(1_000_000)

# %timeit [x * 2 for x in big_array]
# %timeit big_array * 2
# Out:
# 223 ms ± 9.05 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 2.26 ms ± 127 μs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %% [markdown]
# ## Pandas Basics

# %%
df = pd.read_csv('data/raw/starter_data.csv')
df.head(), df.info(), df.describe()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 df = pd.read_csv('data/raw/starter_data.csv')
#       2 df.head(), df.info(), df.describe()
#
# File D:\Program_tools\Python\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
#     863     delimiter,
#    (...)    869     dtype_backend=dtype_backend,
#     870 )
#     871 kwds.update(kwds_defaults)
# --> 873 return _read(filepath_or_buffer, kwds)
#
# File D:\Program_tools\Python\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:300, in _read(filepath_or_buffer, kwds)
#     297 _validate_names(kwds.get("names", None))
#     299 # Create the parser.
# --> 300 parser = TextFileReader(filepath_or_buffer, **kwds)
#     302 if chunksize or iterator:
#     303     return parser
#
# File D:\Program_tools\Python\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1645, in TextFileReader.__init__(self, f, engine, **kwds)
#    1642     self.options["has_index_names"] = kwds["has_index_names"]
#    1644 self.handles: IOHandles | None = None
# -> 1645 self._engine = self._make_engine(f, self.engine)
#
# File D:\Program_tools\Python\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1904, in TextFileReader._make_engine(self, f, engine)
#    1902     if "b" not in mode:
#    1903         mode += "b"
# -> 1904 self.handles = get_handle(
#    1905     f,
#    1906     mode,
#    1907     encoding=self.options.get("encoding", None),
#    1908     compression=self.options.get("compression", None),
#    1909     memory_map=self.options.get("memory_map", False),
#    1910     is_text=is_text,
#    1911     errors=self.options.get("encoding_errors", "strict"),
#    1912     storage_options=self.options.get("storage_options", None),
#    1913 )
#    1914 assert self.handles is not None
#    1915 f = self.handles.handle
#
# File D:\Program_tools\Python\anaconda3\Lib\site-packages\pandas\io\common.py:930, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     925 elif isinstance(handle, str):
#     926     # Check whether the filename is to be opened in binary mode.
#     927     # Binary mode does not support 'encoding' and 'newline'.
#     928     if ioargs.encoding and "b" not in ioargs.mode:
#     929         # Encoding
# --> 930         handle = open(
#     931             handle,
#     932             ioargs.mode,
#     933             encoding=ioargs.encoding,
#     934             errors=errors,
#     935             newline="",
#     936         )
#     937     else:
#     938         # Binary mode
#     939         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/raw/starter_data.csv'

# %% [markdown]
# ## Groupby & Aggregation

# %%
summary = df.groupby('category').mean(numeric_only=True).reset_index()
os.makedirs('data/processed', exist_ok=True)
summary.to_csv('data/processed/summary.csv', index=False)
summary

# %% [markdown]
# ## Plotting

# %%
df['value'].hist()
plt.savefig('data/processed/histogram.png')

# %%
from src.utils import get_summary_stats

# %%
get_summary_stats
