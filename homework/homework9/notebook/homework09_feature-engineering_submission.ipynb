# %% [markdown]
# # Stage 09 — Homework Starter Notebook
#
# In the lecture, we learned how to create engineered features. Now it’s your turn to apply those ideas to your own project data.

# %%
# --- packages this notebook needs (uncomment and run once, then re-comment) ---
# !pip install numpy
# !pip install pandas
# !pip install matplotlib

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(0)
n = 100
df = pd.DataFrame({
    'income': np.random.normal(60000, 15000, n).astype(int),
    'monthly_spend': np.random.normal(2000, 600, n).astype(int),
    'credit_score': np.random.normal(680, 50, n).astype(int),
    'region': np.random.choice(['North', 'South', 'East', 'West'], n),
    'default_flag': np.random.choice([0, 1], n, p=[0.8, 0.2]),
})
df.head()
# Out:
#    income  monthly_spend  credit_score region  default_flag
# 0   86460           3129           661   East             0
# 1   66002           1191           668  North             0
# 2   74681           1237           734   West             0
# 3   93613           2581           712  South             1
# 4   88013           1296           712   East             1

# %% [markdown]
# ## Engineered features — one is worked below; add at least two more
#
# At least one of yours must encode a categorical column. `region` is the categorical
# column here; the lecture shows three ways to encode it (one-hot, label, frequency).

# %%
from src.features import create_features
df1=df.copy()
df1 = create_features(df1)

# Worked example 1 of 3 — keep it, or swap in columns of your own.
df['spend_income_ratio'] = df['monthly_spend'] / df['income']
# Write the rationale in the markdown cell below.
# Out:
#     income  monthly_spend  credit_score region  default_flag  \
# 0    86460           3129           661   East             0
# 1    66002           1191           668  North             0
# 2    74681           1237           734   West             0
# 3    93613           2581           712  South             1
# 4    88013           1296           712   East             1
# ..     ...            ...           ...    ...           ...
# 95   70598           1897           736   East             0
# 96   60157           2463           684  South             0
# 97   86788           2494           709   West             0
# 98   61903           3297           660  South             0
# 99   66029           2801           698   West             0
#
#     spend_income_ratio  credit_limit  region_freq
# 0             0.036190      57150060         0.28
# 1             0.018045      44089336         0.22
# 2             0.016564      54815854         0.22
# 3             0.027571      66652456         0.28
# 4             0.014725      62665256         0.28
# ..                 ...           ...          ...
# 95            0.026870      51960128         0.28
# 96            0.040943      41147388         0.28
# 97            0.028737      61532692         0.22
# 98            0.053261      40855980         0.28
# 99            0.042421      46088242         0.22
#
# [100 rows x 8 columns]

# %% [markdown]
# ### Rationale for Feature 1
# It could measure the user's spending habit. Lower ratio indicates conservative spending and strong savings ability. Higher ratio indicates an overspending habit.

# %%
# TODO: Add another feature
df['credit_limit'] = df['income'] * df['credit_score']

# %% [markdown]
# ### Rationale for Feature 2
# It could draw the scale of customers’ ability about how much credit they can safely handle.

# %%
# TODO: Add a third feature. At least one of your three must ENCODE A CATEGORICAL
region_freq = df['region'].value_counts(normalize=True)
df['region_freq'] = df['region'].map(region_freq)
print(df)
#
#   Pick one and say WHY you picked it in the markdown cell below - the three are not
#   interchangeable, and that choice is the point of the exercise.
# Out:
#     income  monthly_spend  credit_score region  default_flag  \
# 0    86460           3129           661   East             0
# 1    66002           1191           668  North             0
# 2    74681           1237           734   West             0
# 3    93613           2581           712  South             1
# 4    88013           1296           712   East             1
# ..     ...            ...           ...    ...           ...
# 95   70598           1897           736   East             0
# 96   60157           2463           684  South             0
# 97   86788           2494           709   West             0
# 98   61903           3297           660  South             0
# 99   66029           2801           698   West             0
#
#     spend_income_ratio  credit_limit  region_freq
# 0             0.036190      57150060         0.28
# 1             0.018045      44089336         0.22
# 2             0.016564      54815854         0.22
# 3             0.027571      66652456         0.28
# 4             0.014725      62665256         0.28
# ..                 ...           ...          ...
# 95            0.026870      51960128         0.28
# 96            0.040943      41147388         0.28
# 97            0.028737      61532692         0.22
# 98            0.053261      40855980         0.28
# 99            0.042421      46088242         0.22
#
# [100 rows x 8 columns]

# %% [markdown]
# ### Rationale for Feature 3
# It shows the area distribution of different customs, which can help to describe the level of different area.
