# %% [markdown]
# # Environment & Config Check

# %%
import sys, os
print("Python version:", sys.version)
print("Interpreter path:", sys.executable)
# Out:
# Python version: 3.14.6 | packaged by Anaconda, Inc. | (main, Jul  9 2026, 14:29:05) [MSC v.1942 64 bit (AMD64)]
# Interpreter path: D:\Program_tools\Python\anaconda3\python.exe

# %%
try:
    import numpy as np
    from dotenv import load_dotenv
    print("Imports OK")
except Exception as e:
    print("Import error:", e)
    raise
# Out:
# Imports OK

# %%
from pathlib import Path
load_dotenv()  # looks for a .env file in the current and parent directories
# Out:
# True

# %%
# src/config.py (inline demo)
from typing import Optional

def get_key(name: str, default: Optional[str] = None) -> Optional[str]:
    return os.getenv(name, default)

PROJECT_ROOT = Path.cwd()
print("PROJECT_ROOT:", PROJECT_ROOT)
# Out:
# PROJECT_ROOT: C:\Users\ASUS\Desktop\bootcamp_Yuzhen_Chen\homework\homework2\notebooks

# %%
api_key_present = get_key("API_KEY")
print("API_KEY present:", api_key_present)
# Out:
# API_KEY present: dummy_key_123

# %%
arr = np.array([1, 2, 3, 4, 5])
print("Array:", arr)
print("Mean:", arr.mean())
print("Vectorized * 10:", arr * 10)
# Out:
# Array: [1 2 3 4 5]
# Mean: 3.0
# Vectorized * 10: [10 20 30 40 50]
