# %%
import sys, os
print("Python version:", sys.version)
print("Interpreter path:", sys.executable)
# Out:
# Python version: 3.10.20 | packaged by Anaconda, Inc. | (main, Jun 11 2026, 15:13:20) [MSC v.1942 64 bit (AMD64)]
# Interpreter path: D:\Program_tools\Python\anaconda3\envs\bootcamp_env\python.exe

# %%
try:
    import numpy as np
    from dotenv import load_dotenv
    print("Imports OK")
except Exception as e:
    print("Import error:", e)
    raise
# Out:
# Imports OK

# %%
from pathlib import Path
load_dotenv()  # looks for a .env file in the current and parent directories
print(".env loaded (if present)")
# Out:
# .env loaded (if present)

# %%
# src/config.py (inline demo)
from typing import Optional

def get_key(name: str, default: Optional[str] = None) -> Optional[str]:
    return os.getenv(name, default)

PROJECT_ROOT = Path.cwd()
DATA_DIR = PROJECT_ROOT / "data"
print("PROJECT_ROOT:", PROJECT_ROOT)
print("DATA_DIR:", DATA_DIR)
# Out:
# PROJECT_ROOT: C:\Users\ASUS\camp\bootcamp_Yuzhen_Chen\homework\homework2
# DATA_DIR: C:\Users\ASUS\camp\bootcamp_Yuzhen_Chen\homework\homework2\data

# %%
api_key_present = get_key("API_KEY")
data_dir_env = get_key("DATA_DIR", str(DATA_DIR))
print("API_KEY present:", api_key_present)
print("DATA_DIR from env:", data_dir_env)

# Ensure data directory exists (non-destructive)
Path(data_dir_env).mkdir(parents=True, exist_ok=True)
print("Ensured data directory exists.")
# Out:
# API_KEY present: dummy_key_123
# DATA_DIR from env: ./data
# Ensured data directory exists.

# %%
arr = np.array([1, 2, 3, 4, 5])
print("Array:", arr)
print("Mean:", arr.mean())
print("Vectorized * 10:", arr * 10)
# Out:
# Array: [1 2 3 4 5]
# Mean: 3.0
# Vectorized * 10: [10 20 30 40 50]

# %% [markdown]
# - Your environment creation command
#
#   echo API_KEY=dummy_key_123 > .env
#
#   echo DATA_DIR=./data >> .env
# - Why `.env` matters
#
#   protect information
# - What the NumPy demo shows
#
#   Array: [1 2 3 4 5]
#
#   Mean: 3.0
#
#   Vectorized * 10: [10 20 30 40 50]
